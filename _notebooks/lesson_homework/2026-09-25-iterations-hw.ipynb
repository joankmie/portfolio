# %% [raw]
# ---
# layout: post
# categories: [Python, Iterations]
# lesson_language: Python
# lesson_topic: Iterations
# lesson_part: interactive
# lesson_type: lesson
# title: 3.08 iterations HW
# permalink: /csp/python/iterations/hw
# Authors: Joan Kim
# ---

# %% [markdown]
# ## MCQ
#
# MCQ 3.08 Iterations: 4/4 | answers: A,B,A,B

# %% [markdown]
# ## Popcorn Hack

# %%
alerts = [1, 4, 2, 6, 3, 9, 5]

safe_cutoff = 3

critical_cutoff = 8

action_count = 0
safe_count = 0
total_action_score = 0
critical_found = False

for alert in alerts:
    if alert < safe_cutoff:
        safe_count += 1
        print("Alert " + str(alert) + ": safe, skipping")
        continue

    action_count += 1
    total_action_score += alert
    print("Alert " + str(alert) + ": action needed")

    if alert >= critical_cutoff:
        critical_found = True
        print("Critical alert found - stopping scan")
        break

print("Safe alerts skipped: " + str(safe_count))
print("Action alerts: " + str(action_count))
print("Total action score: " + str(total_action_score))
print("Critical found: " + str(critical_found))
# Out:
# Alert 1: safe, skipping
# Alert 4: action needed
# Alert 2: safe, skipping
# Alert 6: action needed
# Alert 3: action needed
# Alert 9: action needed
# Critical alert found - stopping scan
# Safe alerts skipped: 2
# Action alerts: 4
# Total action score: 22
# Critical found: True

# %% [markdown]
# ## Homework Hack

# %%
server_loads = [12, 45, 28, 82, 35, 95, 60, 15, 90]

safe_cutoff = 50

critical_cutoff = 90

checked_count = 0
action_count = 0
skipped_count = 0
total_score = 0
critical_found = False

for load in server_loads:
    checked_count += 1

    if load < safe_cutoff:
        skipped_count += 1
        print(f"CPU Load {load}%: Normal, no action required")
        continue

    action_count += 1
    total_score += load
    print(f"CPU Load {load}%: WARNING - High load detected")

    if load >= critical_cutoff:
        critical_found = True
        print("CRITICAL OVERLOAD DETECTED: Halting scan and initiating failover.")
        break

print("\n--- Server Load Summary Report ---")
print("Checked: " + str(checked_count))
print("Skipped: " + str(skipped_count))
print("Actions: " + str(action_count))
print("Total score: " + str(total_score))
print("Critical found: " + str(critical_found))
# Out:
# CPU Load 12%: Normal, no action required
# CPU Load 45%: Normal, no action required
# CPU Load 28%: Normal, no action required
# CPU Load 82%: WARNING - High load detected
# CPU Load 35%: Normal, no action required
# CPU Load 95%: WARNING - High load detected
# CRITICAL OVERLOAD DETECTED: Halting scan and initiating failover.
#
# --- Server Load Summary Report ---
# Checked: 6
# Skipped: 4
# Actions: 2
# Total score: 177
# Critical found: True

# %% [markdown]
# Lesson: Python 3.08 Iterations MCQ 3.08: 4/4 | answers: A,A,B,B Popcorn: completed loop variable, thresholds, counters, continue, and break (yes) Homework: list length = 9 Homework: thresholds = safe: 50, critical: 90 Homework: final checked count = 6 Homework: final action count = 2 Homework: critical found = yes
